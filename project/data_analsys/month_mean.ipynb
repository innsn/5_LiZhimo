# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv("D:/计算机大三上/大数据分析实践/project/CN-Reanalysis201301/201301/CN-Reanalysis-daily-2013010100.csv")
# filter_data = []
# filtered_temp = df.query("` lat` == 18.33 and ` lon` == 109.52")
# filter_data.append(filtered_temp[' CO(毫克每立方米)'].values)
# for date in range(2,32):
#     with open("D:/计算机大三上/大数据分析实践/project/CN-Reanalysis201301/201301/CN-Reanalysis-daily-201301{}00.csv".format(str(date).zfill(2))) as f:
#         df_temp = pd.read_csv(f)
#         filtered_temp = df_temp.query("` lat` == 18.33 and ` lon` == 109.52")
#         filter_data.append(filtered_temp[' CO(毫克每立方米)'].values)
#         df = pd.concat([df,df_temp])

# %%
df = pd.read_csv("D:/计算机大三上/大数据分析实践/project/CN-Reanalysis201301/201301/CN-Reanalysis-daily-2013010100.csv")
df.columns
# Out:
# Index(['PM2.5(微克每立方米)', ' PM10(微克每立方米)', ' SO2(微克每立方米)', ' NO2(微克每立方米)',
#        ' CO(毫克每立方米)', ' O3(微克每立方米)', ' U(m/s)', ' V(m/s)', ' TEMP(K)',
#        ' RH(%)', ' PSFC(Pa)', ' lat', ' lon', ' '],
#       dtype='object')

# %%
df = df.drop(df.columns[-1], axis=1)
last_column = df.iloc[:, [-1,-2]]
df = df.drop(columns=[' O3(微克每立方米)', ' U(m/s)', ' V(m/s)', ' TEMP(K)',
       ' RH(%)', ' PSFC(Pa)'])

# %%
df[' CO(毫克每立方米)'] = df[' CO(毫克每立方米)'] * 1000
total = df.iloc[:,0:5].sum(axis=1)
df = df.iloc[:, :-2].div(total, axis=0)

# %%
df = pd.concat([df, last_column], axis=1)
df
# Out:
#        PM2.5(微克每立方米)   PM10(微克每立方米)   SO2(微克每立方米)   NO2(微克每立方米)   CO(毫克每立方米)  \
# 0           0.058242       0.067896      0.024928      0.013199     0.835735
# 1           0.058500       0.068675      0.026599      0.015019     0.831208
# 2           0.058563       0.068550      0.027857      0.015132     0.829898
# 3           0.061112       0.071554      0.028468      0.014509     0.824357
# 4           0.057339       0.065089      0.022202      0.010431     0.844939
# ...              ...            ...           ...           ...          ...
# 42244       0.001038       0.001173      0.002302      0.002573     0.992914
# 42245       0.000585       0.000675      0.006569      0.002340     0.989832
# 42246       0.000630       0.000720      0.006790      0.002518     0.989342
# 42247       0.000675       0.000810      0.005716      0.002700     0.990099
# 42248       0.000765       0.000900      0.005041      0.003150     0.990144
#
#           lon    lat
# 0      109.25  18.34
# ...

# %%
g_mean = group.mean()
g_mean
# Out:
#               PM2.5(微克每立方米)   PM10(微克每立方米)   SO2(微克每立方米)   NO2(微克每立方米)  \
#  lat   lon
# 18.33 109.52      32.806129      38.621613      6.909355      3.790000
#       109.66      33.593226      39.984839      6.691613      3.482581
# 18.34 109.25      31.210000      36.620968      6.459677      3.480968
#       109.38      31.562581      37.155161      6.722581      3.806774
# 18.45 109.81      32.557419      39.623226      6.811935      3.961935
# ...                     ...            ...           ...           ...
# 53.45 122.58       0.933871       1.091613      1.190323      1.310000
# 53.47 122.37       0.889677       1.030000      1.178065      1.158387
#       123.66       0.799355       0.931290      1.522581      1.081935
# 53.49 123.45       0.817097       0.947742      1.415484      1.035161
# 53.51 123.24       0.795484       0.918710      1.268065      0.952903
#
#                CO(毫克每立方米)   O3(微克每立方米)    U(m/s)    V(m/s)     TEMP(K)  \
#  lat   lon
# ...

# %%
g_var = group.var()
g_var
# Out:
#               PM2.5(微克每立方米)   PM10(微克每立方米)   SO2(微克每立方米)   NO2(微克每立方米)  \
#  lat   lon
# 18.33 109.52     296.767951     323.439561     11.331126      1.632327
#       109.66     322.033389     349.033799     11.763394      1.996786
# 18.34 109.25     254.923253     281.327642     10.385390      1.462542
#       109.38     264.678600     291.263732     10.803673      1.504723
# 18.45 109.81     251.546573     309.485783     13.344889      3.187663
# ...                     ...            ...           ...           ...
# 53.45 122.58       0.837365       1.010407      0.592477      0.208893
# 53.47 122.37       0.776450       0.925047      0.589149      0.153281
#       123.66       0.771086       0.944638      0.340553      0.261036
# 53.49 123.45       0.821075       1.001071      0.459452      0.259352
# 53.51 123.24       0.813032       0.981138      0.512856      0.230521
#
#                CO(毫克每立方米)   O3(微克每立方米)    U(m/s)    V(m/s)   TEMP(K)  \
#  lat   lon
# ...

# %%
max_layer = g_mean+g_var/g_mean
max_layer
# Out:
#               PM2.5(微克每立方米)   PM10(微克每立方米)   SO2(微克每立方米)   NO2(微克每立方米)  \
#  lat   lon
# 18.33 109.52      41.852242      46.996187      8.549324      4.220693
#       109.66      43.179486      48.713992      8.449544      4.055945
# 18.34 109.25      39.377999      44.303114      8.067403      3.901122
#       109.38      39.948416      44.994280      8.329653      4.202049
# 18.45 109.81      40.283664      47.433942      8.770981      4.766508
# ...                     ...            ...           ...           ...
# 53.45 122.58       1.830531       2.017222      1.688067      1.469461
# 53.47 122.37       1.762409       1.928104      1.678164      1.290710
#       123.66       1.763991       1.945623      1.746249      1.323203
# 53.49 123.45       1.821965       2.004012      1.740074      1.285704
# 53.51 123.24       1.817544       1.986662      1.672505      1.194818
#
#                CO(毫克每立方米)   O3(微克每立方米)    U(m/s)    V(m/s)     TEMP(K)  \
#  lat   lon
# ...

# %%
min_layer = max_layer = g_mean - g_var/g_mean
min_layer
# Out:
#               PM2.5(微克每立方米)   PM10(微克每立方米)   SO2(微克每立方米)   NO2(微克每立方米)  \
#  lat   lon
# 18.33 109.52      23.760016      30.247039      5.269386      3.359307
#       109.66      24.006966      31.255685      4.933682      2.909217
# 18.34 109.25      23.042001      28.938821      4.851952      3.060814
#       109.38      23.176745      29.316042      5.115508      3.411499
# 18.45 109.81      24.831175      31.812509      4.852890      3.157363
# ...                     ...            ...           ...           ...
# 53.45 122.58       0.037211       0.166003      0.692578      1.150539
# 53.47 122.37       0.016945       0.131896      0.677965      1.026065
#       123.66      -0.165281      -0.083042      1.298912      0.840668
# 53.49 123.45      -0.187771      -0.108528      1.090894      0.784618
# 53.51 123.24      -0.226576      -0.149243      0.863624      0.710989
#
#                CO(毫克每立方米)   O3(微克每立方米)    U(m/s)    V(m/s)     TEMP(K)  \
#  lat   lon
# ...
