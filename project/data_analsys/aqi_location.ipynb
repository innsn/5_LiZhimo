# %%
import pandas as pd
import numpy as np

# 读取数据并删除重复项
df = pd.read_csv("only_all_date_type.csv", index_col=False)
df = df.drop_duplicates(subset=["省", "市", "date", "type"], keep='first')

df = df.drop(df[(df['省'] == '[]') & (df['市'] == '[]')].index)
df['市'].replace('[]', np.nan, inplace=True)
df['市'].fillna(df['省'], inplace=True)

# %%
pivot_df = df.pivot(index=['省','市'], columns='date', values='type')
pivot_df.columns.name = None
pivot_df = pivot_df.reset_index()
pivot_df.to_csv('city_type_date.csv',index=False)

# %%
pivot_df
# Out:
#            省        市 2013/01/01 2013/01/02 2013/01/03 2013/01/04 2013/01/05  \
# 0        上海市      上海市       偏燃煤型        标准型        标准型        标准型        标准型
# 1    中华人民共和国  中华人民共和国       偏燃煤型       偏燃煤型        标准型        标准型        标准型
# 2        云南省      临沧市       偏燃煤型       偏燃煤型       偏燃煤型       偏燃煤型        标准型
# 3        云南省      丽江市        标准型        标准型       偏二次型        标准型        标准型
# 4        云南省      保山市       偏燃煤型       偏燃煤型       偏燃煤型      偏机动车型        标准型
# ..       ...      ...        ...        ...        ...        ...        ...
# 354     黑龙江省      绥化市       偏二次型        标准型       偏燃煤型       偏燃煤型       偏燃煤型
# 355     黑龙江省      鸡西市      偏机动车型       偏二次型        标准型      偏机动车型       偏燃煤型
# 356     黑龙江省      鹤岗市        标准型        标准型        标准型        标准型       偏二次型
# 357     黑龙江省      黑河市        标准型        标准型        标准型       偏燃煤型        标准型
# 358     黑龙江省    齐齐哈尔市        标准型        标准型        标准型        标准型        标准型
#
# ...

# %%
df.set_index(['市'], inplace=True)

# 使用 unstack() 方法将数据重塑，纵轴为时间，横轴为城市
unstacked_df = df['type'].unstack()

# 显示转换后的数据框架
print(unstacked_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\计算机大三上\大数据分析实践\project\my_code\aqi_location.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/d%3A/%E8%AE%A1%E7%AE%97%E6%9C%BA%E5%A4%A7%E4%B8%89%E4%B8%8A/%E5%A4%A7%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90%E5%AE%9E%E8%B7%B5/project/my_code/aqi_location.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df.set_index(['市'], inplace=True)
#       <a href='vscode-notebook-cell:/d%3A/%E8%AE%A1%E7%AE%97%E6%9C%BA%E5%A4%A7%E4%B8%89%E4%B8%8A/%E5%A4%A7%E6%95%B0%E6%8D%AE%E5%88%86%E6%9E%90%E5%AE%9E%E8%B7%B5/project/my_code/aqi_location.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> # 使用 unstack() 方法将数据重塑，纵轴为时间，横轴为城市
# ...

# %%
df
# Out:
#              市        date  type
# 省
# 上海市         []  2013/01/01  偏燃煤型
# 中华人民共和国     []  2013/01/01  偏燃煤型
# 云南省        临沧市  2013/01/01  偏燃煤型
# 云南省        丽江市  2013/01/01   标准型
# 云南省        保山市  2013/01/01  偏燃煤型
# ...        ...         ...   ...
# 黑龙江省       绥化市  2018/12/31   标准型
# 黑龙江省       鸡西市  2018/12/31   标准型
# 黑龙江省       鹤岗市  2018/12/31   标准型
# 黑龙江省       黑河市  2018/12/31   标准型
# 黑龙江省     齐齐哈尔市  2018/12/31   标准型
#
# [775799 rows x 3 columns]

# %%
import pandas as pd

df = pd.read_csv("only_all_date_type.csv", index_col=False)
df = df.drop_duplicates(subset=["省", "市", "date", "type"], keep='first')

# 将索引设置为 ['省', '市']
# df.set_index(['省', '市'], inplace=True)

# 将筛选条件进行修改，使用逻辑运算符 &
df = df[(df['省'] == '云南省') & (df['市'] == '丽江市')]
# df = df.drop(columns=['省','市'])

df.reset_index(drop=True, inplace=True)
df_transposed = df.T

# 将结果保存到 CSV 文件中，不包含索引
df_transposed.head()
# df_transposed.to_csv('丽江.csv', index=False, header=False)
# Out:
#             0           1           2           3           4           5     \
# 省            云南省         云南省         云南省         云南省         云南省         云南省
# 市            丽江市         丽江市         丽江市         丽江市         丽江市         丽江市
# date  2013/01/01  2013/01/02  2013/01/03  2013/01/04  2013/01/05  2013/01/06
# type         标准型         标准型        偏二次型         标准型         标准型         标准型
#
#             6           7           8           9     ...        2151  \
# 省            云南省         云南省         云南省         云南省  ...         云南省
# 市            丽江市         丽江市         丽江市         丽江市  ...         丽江市
# date  2013/01/07  2013/01/08  2013/01/09  2013/01/10  ...  2018/12/22
# type         标准型        偏二次型        偏二次型        偏二次型  ...       偏机动车型
#
#             2152        2153        2154        2155        2156        2157  \
# 省            云南省         云南省         云南省         云南省         云南省         云南省
# ...

# %%
data.loc[data['市'] =='[]','市'] = data.loc[data['市'] =='[]','省']

# %%
data.loc[data['市'] == '那曲地区']
# Out:
#        Unnamed: 0.2  PM2.5(微克每立方米)   PM10(微克每立方米)   SO2(微克每立方米)   NO2(微克每立方米)  \
# 10510         10510           0.40           0.56          0.05          0.18
# 10511         10511           0.38           0.50          0.05          0.16
# 10523         10523           0.60           0.74          0.07          0.22
# 10524         10524           0.58           0.71          0.07          0.19
# 10525         10525           0.58           0.71          0.07          0.17
# ...             ...            ...            ...           ...           ...
# 22560         22560           0.75           0.80          0.11          0.14
# 22561         22561           0.76           0.81          0.11          0.14
# 22562         22562           0.78           0.83          0.11          0.14
# 22563         22563           0.80           0.85          0.11          0.13
# 22564         22564           0.80           0.85          0.11          0.13
#
# ...

# %%
data.loc[data['市'] == '北京市']
# Out:
#        Unnamed: 0.1  Unnamed: 0    lat     lon    市    省  区/县
# 21946         21946         481  39.63  115.62  北京市  北京市  房山区
# 21947         21947         482  39.61  115.80  北京市  北京市  房山区
# 21948         21948         483  39.60  115.97  北京市  北京市  房山区
# 21949         21949         484  39.58  116.15  北京市  北京市  房山区
# 21950         21950         485  39.57  116.32  北京市  北京市  大兴区
# ...             ...         ...    ...     ...  ...  ...  ...
# 24314         24314        1650  40.78  116.49  北京市  北京市  怀柔区
# 24315         24315        1651  40.76  116.67  北京市  北京市  怀柔区
# 24316         24316        1652  40.75  116.85  北京市  北京市  密云区
# 24587         24587        1923  40.91  116.51  北京市  北京市  怀柔区
# 24588         24588        1924  40.90  116.69  北京市  北京市  怀柔区
#
# [72 rows x 7 columns]

# %%
aqi = pd.read_csv('AQI_result13_01_01.csv')
aqi = aqi[[' lat',' lon','AQI']]

# %%
data = pd.merge(data,aqi,how='left',on=[' lat',' lon'])
# Out:
#        Unnamed: 0.1  Unnamed: 0    lat     lon        市      省      区/县  \
# 0                 0           0  18.34  109.25      三亚市    海南省      天涯区
# 1                 1           1  18.34  109.38      三亚市    海南省      天涯区
# 2                 2           2  18.33  109.52      三亚市    海南省      吉阳区
# 3                 3           3  18.33  109.66      三亚市    海南省      吉阳区
# 4                 4           4  18.49  108.83  乐东黎族自治县    海南省  乐东黎族自治县
# ...             ...         ...    ...     ...      ...    ...      ...
# 42244         42244        1030  29.79   90.31      拉萨市  西藏自治区      当雄县
# 42245         42245        1031  29.81   90.47      拉萨市  西藏自治区      当雄县
# 42246         42246        1032  29.82   90.62      拉萨市  西藏自治区    堆龙德庆区
# 42247         42247        1033  29.84   90.78      拉萨市  西藏自治区    堆龙德庆区
# 42248         42248        1034  29.86   90.93      拉萨市  西藏自治区      林周县
#
#              AQI
# 0      28.871429
# 1      29.157143
# 2      30.242857
# 3      31.771429
# ...

# %%
df=pd.read_csv("D:/计算机大三上/大数据分析实践/project/CN-Reanalysis201301/201301/CN-Reanalysis-daily-2013010100.csv")
df = pd.merge(df,data,how='left',on=[' lat',' lon'])
df.to_csv('temp.csv')
