# %%
import pandas as pd
data = pd.read_csv('test.csv')

# %%
# 数据过滤
df_filter = data.loc[(data['from_level'] == '一般节点') & (data['traffic'] != 0)]
df_filter
# Out:
#       from_dev  from_port from_city from_level   to_dev  to_port to_city  \
# 0         47.0       71.0        通辽       一般节点   1756.0    585.0      北京
# 1         47.0       74.0        通辽       一般节点   1756.0    776.0      北京
# 2         47.0      240.0        通辽       一般节点   1756.0    802.0      北京
# 3         47.0      241.0        通辽       一般节点   1997.0    464.0      天津
# 4         47.0      242.0        通辽       一般节点    474.0    672.0     哈尔滨
# ...        ...        ...       ...        ...      ...      ...     ...
# 1097    2473.0     1460.0        吉林       一般节点    591.0    586.0      绥化
# 1103   36036.0       18.0        长春       一般节点   3443.0    650.0      青岛
# 1104      63.0        6.0        通辽       一般节点  36036.0     20.0      长春
# 1107   36036.0       52.0        长春       一般节点   1129.0    171.0      上海
# 1115   36036.0      499.0        长春       一般节点   1257.0    178.0      上海
#
#      to_level       traffic     bandwidth
# 0        网络核心  3.677962e+10  1.000000e+11
# 1        网络核心  3.660713e+10  1.000000e+11
# 2        网络核心  3.603489e+10  1.000000e+11
# 3        网络核心  4.233391e+10  1.000000e+11
# 4        一般节点  1.130008e+10  1.000000e+11
# ...       ...           ...           ...
# 1097     一般节点  9.165302e+10  1.000000e+11
# 1103     网络核心  4.350363e+10  1.000000e+11
# 1104     一般节点  1.871659e+10  1.000000e+11
# 1107     网络核心  2.760267e+10  1.000000e+11
# 1115     网络核心  4.117194e+10  1.000000e+11
#
# [554 rows x 10 columns]

# %%
# 加权采样
conversion = {'一般节点':1, '网络核心':5}
data_weight = data.copy()
data_weight['to_level'].replace(conversion,inplace=True)
df_weight = data_weight.sample(n = 50, weights='to_dev', random_state=1)
df_weight.head(10)
# Out:
#      from_dev  from_port from_city from_level   to_dev  to_port to_city  \
# 458    1997.0       39.0        天津       网络核心  36422.0    230.0      天津
# 703    2841.0      483.0        郑州       网络核心  36539.0   1140.0      杭州
# 0        47.0       71.0        通辽       一般节点   1756.0    585.0      北京
# 358     180.0      210.0      呼和浩特       一般节点   1756.0    642.0      北京
# 140     591.0       56.0        绥化       一般节点  36036.0     52.0      长春
# 86      180.0      226.0      呼和浩特       一般节点  36036.0     20.0      长春
# 153     591.0     1028.0        绥化       一般节点  36422.0    268.0      天津
# 413     591.0       27.0        绥化       一般节点  36422.0    124.0      天津
# 449     787.0      316.0        玉溪       一般节点  36422.0    394.0      天津
# 562      96.0      111.0      呼和浩特       一般节点   3443.0    101.0      青岛
#
#      to_level       traffic     bandwidth
# 458       5.0  4.048337e+10  1.000000e+11
# 703       1.0  1.785259e+10  1.000000e+11
# 0         5.0  3.677962e+10  1.000000e+11
# 358       5.0  1.290000e+11  1.000000e+11
# 140       1.0  6.671652e+10  1.000000e+11
# 86        1.0  1.383894e+10  1.000000e+11
# 153       5.0  0.000000e+00  1.000000e+11
# 413       5.0  4.120743e+10  1.000000e+11
# 449       5.0  4.039894e+10  1.000000e+11
# 562       5.0  1.965959e+10  1.000000e+11

# %%
# 分层采样
data['to_level'].value_counts() # 查看一般节点和网络核心数量,得到分层抽样个数：一般19 网络31
group = data.groupby('to_level')
df_stratified = group.apply(lambda x: x.sample(n=31) if x.name == '网络核心' else x.sample(n=19))
df_stratified
# Out:
#                from_dev  from_port from_city from_level   to_dev  to_port  \
# to_level
# 一般节点     809    36422.0      124.0        天津       网络核心    474.0    673.0
#          765     1536.0     2226.0        广州       网络核心    180.0     28.0
#          148      591.0      558.0        绥化       一般节点  36036.0    499.0
#          400      474.0     1374.0       哈尔滨       一般节点    591.0     23.0
#          272     2050.0      350.0       石家庄       网络核心   2473.0    941.0
#          1031     591.0       23.0        绥化       一般节点     96.0    152.0
#          396      474.0     1269.0       哈尔滨       一般节点     96.0    152.0
#          831    36422.0      258.0        天津       网络核心    591.0     13.0
#          761     3643.0      902.0        武汉       网络核心    180.0     10.0
#          974     1536.0     1882.0        广州       网络核心     63.0    224.0
#          773     2473.0      762.0        吉林       一般节点    180.0     84.0
#          849     2360.0      215.0        太原       网络核心    591.0    586.0
#          914     3227.0      195.0        济南       网络核心     47.0    249.0
#          1104      63.0        6.0        通辽       一般节点  36036.0     20.0
#          447      787.0       63.0        玉溪       一般节点  36036.0     54.0
#          7         47.0      250.0        通辽       一般节点   2473.0    762.0
#          674      591.0      586.0        绥化       一般节点     47.0    243.0
#          872     2194.0      406.0        唐山       网络核心    787.0    316.0
#          376      474.0      460.0       哈尔滨       一般节点   3757.0    122.0
# 网络核心     315       96.0      117.0      呼和浩特       一般节点   1257.0    581.0
#          562       96.0      111.0      呼和浩特       一般节点   3443.0    101.0
#          415      591.0       56.0        绥化       一般节点  36422.0    230.0
#          313       96.0      111.0      呼和浩特       一般节点   2360.0    197.0
#          287       47.0      260.0        通辽       一般节点   3213.0    597.0
#          114      474.0      682.0       哈尔滨       一般节点   1536.0    585.0
#          44        96.0      127.0      呼和浩特       一般节点   1756.0   1027.0
#          174      787.0      316.0        玉溪       一般节点   1257.0    177.0
#          693     1997.0       41.0        天津       网络核心   1997.0    729.0
#          280       47.0      243.0        通辽       一般节点   3213.0    562.0
#          952     2701.0      619.0        大连       网络核心   2050.0    295.0
#          105      474.0      474.0       哈尔滨       一般节点   2360.0    213.0
#          1071    1756.0     1187.0        北京       网络核心   2841.0    545.0
#          353      180.0      188.0      呼和浩特       一般节点   1536.0   2274.0
#          607     2549.0      835.0        沈阳       网络核心  36422.0    324.0
#          210     1997.0      193.0        天津       网络核心   3213.0    606.0
#          667    36539.0     1140.0        杭州       一般节点   3227.0    781.0
#          945     3443.0      101.0        青岛       网络核心   2050.0    276.0
#          186     1997.0       42.0        天津       网络核心   3227.0    493.0
#          135      591.0       17.0        绥化       一般节点   3443.0    186.0
#          565    36422.0      350.0        天津       网络核心   1129.0    546.0
#          717     2473.0     1043.0        吉林       一般节点  36422.0    324.0
#          113      474.0      678.0       哈尔滨       一般节点   1997.0    124.0
#          713     1756.0     1008.0        北京       网络核心   1536.0     47.0
#          899     1257.0      178.0        上海       网络核心   2050.0    332.0
#          103      474.0      472.0       哈尔滨       一般节点   2050.0    312.0
#          222     1997.0      245.0        天津       网络核心   1756.0   1128.0
#          573    36036.0       20.0        长春       一般节点    235.0   1621.0
#          0         47.0       71.0        通辽       一般节点   1756.0    585.0
#          56        96.0      346.0      呼和浩特       一般节点   1257.0    138.0
#          68       180.0       30.0      呼和浩特       一般节点    235.0   1661.0
#
#               to_city to_level       traffic     bandwidth
# to_level
# 一般节点     809      哈尔滨     一般节点  3.882399e+10  1.000000e+11
#          765     呼和浩特     一般节点  1.350000e+11  1.000000e+11
#          148       长春     一般节点  6.475345e+10  1.000000e+11
#          400       绥化     一般节点  8.917871e+09  1.000000e+11
#          272       吉林     一般节点  4.378758e+10  1.000000e+11
#          1031    呼和浩特     一般节点  3.756481e+10  1.000000e+11
#          396     呼和浩特     一般节点  2.204430e+10  1.000000e+11
#          831       绥化     一般节点  9.319356e+10  1.000000e+11
#          761     呼和浩特     一般节点  1.785259e+10  1.000000e+11
#          974       通辽     一般节点  2.822784e+10  1.000000e+11
#          773     呼和浩特     一般节点  9.319356e+10  1.000000e+11
#          849       绥化     一般节点  4.402305e+10  1.000000e+11
#          914       通辽     一般节点  0.000000e+00  1.000000e+11
#          1104      长春     一般节点  1.871659e+10  1.000000e+11
#          447       长春     一般节点  1.060549e+10  1.000000e+11
#          7         吉林     一般节点  7.720147e+09  1.000000e+11
#          674       通辽     一般节点  2.310000e+11  1.000000e+11
#          872       玉溪     一般节点  1.871659e+10  1.000000e+11
#          376       福州     一般节点  2.063768e+10  1.000000e+11
# 网络核心     315       上海     网络核心  7.553555e+10  1.000000e+11
#          562       青岛     网络核心  1.965959e+10  1.000000e+11
#          415       天津     网络核心  4.048337e+10  1.000000e+11
#          313       太原     网络核心  1.800000e+11  1.000000e+11
#          287       重庆     网络核心  9.741635e+10  1.000000e+11
#          114       广州     网络核心  6.885369e+10  1.000000e+11
#          44        北京     网络核心  8.917187e+10  1.000000e+11
#          174       上海     网络核心  2.527145e+10  1.000000e+11
#          693       天津     网络核心  3.882399e+10  1.000000e+11
#          280       重庆     网络核心  9.851322e+10  1.000000e+11
#          952      石家庄     网络核心  6.473446e+10  1.000000e+11
#          105       太原     网络核心  5.093401e+10  1.000000e+11
#          1071      郑州     网络核心  1.160000e+11  1.000000e+11
#          353       广州     网络核心  3.574563e+10  1.000000e+11
#          607       天津     网络核心  4.473394e+10  1.000000e+11
#          210       重庆     网络核心  3.480596e+10  1.000000e+11
#          667       济南     网络核心  3.443335e+10  1.000000e+11
#          945      石家庄     网络核心  4.178541e+10  1.000000e+11
#          186       济南     网络核心  8.980183e+10  1.000000e+11
#          135       青岛     网络核心  1.925957e+10  1.000000e+11
#          565       上海     网络核心  2.602796e+10  1.000000e+11
#          717       天津     网络核心  4.473394e+10  1.000000e+11
#          113       天津     网络核心  4.294458e+10  1.000000e+11
#          713     鄂尔多斯     网络核心  4.178541e+10  1.000000e+11
#          899      石家庄     网络核心  4.355991e+10  1.000000e+11
#          103      石家庄     网络核心  4.576477e+10  1.000000e+11
#          222       北京     网络核心  2.120000e+11  1.000000e+11
#          573       北京     网络核心  5.713317e+10  1.000000e+11
#          0         北京     网络核心  3.677962e+10  1.000000e+11
#          56        上海     网络核心  1.624315e+10  1.000000e+11
#          68        北京     网络核心  1.340000e+11  1.000000e+11

# %%
# 随机采样
df_rand = data.sample(n=50, random_state=1)
df_rand.head()
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 934     2994.0      488.0        洛阳       网络核心  1997.0    724.0      天津
# 120      474.0     1259.0       哈尔滨       一般节点  3227.0    787.0      济南
# 694     2549.0     1070.0        沈阳       网络核心  2994.0    270.0      洛阳
# 965     3443.0     1104.0        青岛       网络核心    63.0     10.0      通辽
# 1101    1385.0     1490.0        广州       网络核心  2194.0    450.0      唐山
#
#      to_level       traffic     bandwidth
# 934      网络核心  1.900928e+10  1.000000e+11
# 120      网络核心  3.073302e+10  1.000000e+11
# 694      网络核心  3.036292e+10  1.000000e+11
# 965      一般节点  4.402305e+10  1.000000e+11
# 1101     网络核心  4.150792e+10  1.000000e+11

# %%
# 查看一般节点和网络核心抽取样本数
print('rand', data['to_level'].value_counts() / (699+419)*50,'\n')
print('rand', df_rand['to_level'].value_counts(),'\n')
print('weight',df_weight['to_level'].value_counts(),'\n')
print('stratified', df_stratified['to_level'].value_counts())
# Out:
# rand to_level
# 网络核心    31.261181
# 一般节点    18.738819
# Name: count, dtype: float64
#
# rand to_level
# 网络核心    33
# 一般节点    15
# Name: count, dtype: int64
#
# weight to_level
# 5.0    39
# 1.0    11
# Name: count, dtype: int64
#
# stratified to_level
# 网络核心    31
# 一般节点    19
# Name: count, dtype: int64
